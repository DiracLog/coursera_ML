# %%
import pandas as pd
import itertools
from numpy import exp
import numpy as np
from scipy.spatial import distance

# %%
path_to_data = "C:/study/data/"

# %%
df = pd.read_csv(path_to_data + "data-logistic.csv", header=None)

# %%
df.head()
# Out:
#    0         1         2
# 0 -1 -0.663827 -0.138526
# 1  1  1.994596  2.468025
# 2 -1 -1.247395  0.749425
# 3  1  2.309374  1.899836
# 4  1  0.849143  2.407750

# %%
y = df[df.columns[0]]
X = df[df.columns[1:]]
x1 = X[1]
x2 = X[2]

# %%
def sigmoid(x):
    return (1 / (1+exp(-x)))

# %%
def gradient_step(k, C, w1, w2, x1, x2, y):
    """
    function for weights update
    k - step, C - regularization coefficient, 
    w1, w2 - initial weights
    y - target vector
    """

    inkrement1=0
    inkrement2=0
    for i in range(0,len(y)):
        inkrement1 += (k/len(y)) * (y[i]*x1[i]) * (1 - sigmoid(y[i] * (w1*x1[i] + w2*x2[i])))
        inkrement2 += (k/len(y)) * (y[i]*x2[i]) * (1 - sigmoid(y[i] * (w1*x1[i] + w2*x2[i])))
    w1 += inkrement1 - k*C*w1
    w2 += inkrement2 - k*C*w2
    return w1,w2

# %%
def gradient_descent(k, C,  w1, w2, x1, x2, y, iterations=1e4, stop=1e-5):
    i = 0
    while True:
        i+=1
        w1_s = w1
        w2_s = w2
        w1, w2 = gradient_step(k=k, C=C, w1=w1, w2=w2, x1=x1, x2=x2, y=y)
        if distance.euclidean((w1,w2),(w1_s,w2_s)) < stop or i > iterations:
            break
    return (w1,w2)

# %%
def get_probs(w1,w2,x1,x2):
    probs = []
    for i in range(0, len(x1)):
        probs.append(sigmoid(w1*x1[i] + w2*x2[i]))
    return probs

# %%
w1,w2 = gradient_descent(k=0.1, C=10, w1=0, w2=0, x1=x1, x2=x2, y=y)

# %%
w1, w2
# Out:
# (0.02855875454623422, 0.024780137249735528)

# %%
probs = get_probs(w1,w2,x1,x2)

# %%
probs
# Out:
# [0.4944025475025294,
#  0.5294960008513981,
#  0.4957368033419395,
#  0.5282277128147582,
#  0.520966409819608,
#  0.5062604414439291,
#  0.5300823367598685,
#  0.508618029218254,
#  0.4887377640717866,
#  0.5175760055944163,
#  0.5019164771626575,
#  0.5015494554061638,
#  0.4934116084179819,
#  0.5055899757833094,
#  0.5222836185848817,
#  0.5043425922116569,
#  0.49295960028999414,
#  0.5191125020027608,
#  0.5219557272753146,
#  0.5348921372802882,
#  0.5021801475793493,
#  0.381319645530652,
#  0.48731919498878196,
#  0.4920696728364942,
#  0.5120357324177529,
#  0.5039500221633949,
#  0.5306912927485266,
#  0.5410776318394168,
#  0.4983937869387338,
#  0.5135725993580922,
#  0.49451210360457637,
#  0.5024753364374631,
#  0.546004822044189,
#  0.5326205306762868,
#  0.5073897010518211,
#  0.5137854596695193,
#  0.5341760293556234,
#  0.5230097578402351,
#  0.507203224404265,
#  0.48687742865880373,
#  0.48371985306616627,
#  0.5238672509965985,
#  0.5211508283180487,
#  0.5268192802729714,
#  0.5325981866754738,
#  0.4951194257046846,
#  0.5144646469057068,
#  0.5071661682688677,
#  0.4849470565121796,
#  0.5334962012798995,
#  0.5027806964141719,
#  0.5132358334617161,
#  0.4931853823307084,
#  0.5239069403281185,
#  0.5182396132680228,
#  0.506731716450253,
#  0.523001500688608,
#  0.497282296968528,
#  0.5344790205745548,
#  0.534628820005288,
#  0.5063693902810561,
#  0.5263944869352305,
#  0.49731473610073396,
#  0.5167146178393006,
#  0.49774496746001945,
#  0.5056883157139948,
#  0.4981289756616761,
#  0.503732512258445,
#  0.4903551178445406,
#  0.538685261583687,
#  0.5229943945240482,
#  0.5058417106553666,
#  0.48733166622540214,
#  0.5139391321915179,
#  0.5328580326510763,
#  0.49870700757462794,
#  0.529572426434144,
#  0.5308731467898141,
#  0.4917066862634884,
#  0.5490699908181181,
#  0.5257948214558412,
#  0.4961009207076551,
#  0.36814353537128297,
#  0.5053722968871939]

# %%
from sklearn.metrics import roc_auc_score

# %% [markdown]
# #### with regularization

# %%
round(roc_auc_score(y, probs), 3)
# Out:
# 0.936

# %% [markdown]
# #### without regularization

# %%
w1,w2 = gradient_descent(k=0.1, C=0, w1=0, w2=0, x1=x1, x2=x2, y=y)

# %%
w1,w2
# Out:
# (0.2878116204717764, 0.09198330215925439)

# %%
probs = get_probs(w1,w2,x1,x2)

# %%
round(roc_auc_score(y, probs), 3)
# Out:
# 0.927

# %%
res1 = []
for i,j,k in zip(y,x1,x2):
    res1.append((i,j,k))

# %%
res2 = []
for i in range(0,len(y)):
    res2.append((y[i], x1[i], x2[i]))

# %%
# Out:
# [(-1, -0.6638265368249999, -0.138525716794),
#  (1, 1.9945955012799998, 2.46802467614),
#  (-1, -1.24739491636, 0.749424636303),
#  (1, 2.30937424866, 1.89983555937),
#  (1, 0.849143314149, 2.40774982339),
#  (1, 1.4542709504, -0.6654157090030001),
#  (1, 2.25422743269, 2.2637858535),
#  (-1, -0.06757951660559999, 1.46914109556),
#  (-1, -0.861960913075, -0.824855578346),
#  (1, 0.699178929108, 2.03248760563),
#  (-1, -0.16147996103599999, 0.495461854788),
#  (-1, -0.14710226136600002, 0.41964653929300005),
#  (-1, 0.0802959559549, -1.1560970761),
#  (-1, 1.72065543353, -1.08066154412),
#  (1, 1.57395764659, 1.7854335648),
#  (-1, 1.16844517782, -0.645619241065),
#  (-1, -0.06662736015, -1.05974658502),
#  (1, 1.1633547323, 1.7458867561099998),
#  (1, 2.0969697873400004, 1.1296376586599999),
#  (1, 3.03570513408, 2.14283779581),
#  (-1, 0.831852058628, -0.606776832016),
#  (1, -12.977800215, -4.57305579231),
#  (-1, -0.842603085438, -1.07628156079),
#  (-1, -0.47353672342299996, -0.734473330818),
#  (1, 1.67811148547, 2.0910809135),
#  (-1, 1.01434797537, 0.491369741164),
#  (1, 2.90428924819, 3.3987921871399998),
#  (1, 0.247516987973, 1.66716317109),
#  (-1, -0.539257339664, 1.26508815608),
#  (1, 0.0994917514247, 0.7676924594519999),
#  (-1, 0.8169071226379999, -1.8789463016499999),
#  (-1, 1.13143727039, 0.7795318346619999),
#  (-1, 0.556055161118, -1.78241136647),
#  (1, 1.8371518786, 2.03211463165),
#  (-1, 0.623357772465, 0.219793322086),
#  (-1, -0.67491100615, -0.49013790428000004),
#  (1, 0.844981013719, 2.88917951139),
#  (1, 1.7587642038, 0.009576485492809999),
#  (-1, -1.1260470502600002, 1.17503847686),
#  (-1, -0.558989073802, -0.408036044973),
#  (-1, 1.27370523325, 1.86969155422),
#  (1, 2.2332107787099997, 1.86686825431),
#  (1, 0.9326803467039999, 1.54632699002),
#  (-1, -0.838851497492, 0.207051584551),
#  (-1, 0.960556155592, -0.206878757833),
#  (-1, 0.318371785439, -2.52041079395),
#  (1, -0.0579711035843, 1.28007822413),
#  (1, 1.59069297712, 1.16557207662),
#  (1, 2.2874861068, 3.1750127893),
#  (1, 1.11275800896, 2.47511525715),
#  (-1, -0.245411545137, -0.180444910555),
#  (-1, -0.8904430016299999, -0.869161614255),
#  (1, 2.04808800218, 3.14318588365),
#  (1, 1.6473671542100001, 2.29287895734),
#  (1, 0.395264710891, 2.72965991477),
#  (-1, 1.53670507995, 0.6347847922),
#  (1, -9.37143230289, -6.71919886045),
#  (-1, -0.43987999445299997, 1.4746174904),
#  (-1, 0.71961284888, -0.65492815767),
#  (1, 2.94376208903, 1.40848563935),
#  (-1, -0.7635990593240001, -0.10257540573200001),
#  (1, 3.64197606852, 1.30324677502),
#  (-1, -0.11263359276399999, 0.7088282545929999),
#  (1, 1.16324910809, 2.5262928528099997),
#  (-1, -1.7382587344299998, 0.836758278756),
#  (1, 2.0964870453, 2.84392191228),
#  (1, 2.3232693338, 1.42787134783),
#  (1, 3.55567588519, 2.02358555842),
#  (-1, -0.264256809396, 2.4098668254700004),
#  (1, 1.66810292901, 2.0660204499900003),
#  (1, -12.8972510773, -17.6772681159),
#  (1, 1.9188866543, 2.07195955606),
#  (-1, 1.2907542751899999, 0.857004294159),
#  (-1, 0.248407461019, -1.02919534362),
#  (-1, 1.23891171595, -1.1647343366),
#  (1, 3.5139376847300006, 2.94293860027),
#  (-1, -0.9747320324519999, -0.737487095139),
#  (1, 2.17857023587, 4.2283163008999995),
#  (-1, 0.869718820176, 0.794612954576),
#  (1, 4.09144093043, 2.3255489792099997),
#  (-1, 0.594400570732, 0.0723858903714),
#  (1, 1.60078552756, 3.6230601675300003),
#  (1, 1.75356482216, 2.72479147224),
#  (1, 1.45557192822, 2.82991212468),
#  (1, 0.9710881012270001, 0.6777758935930001),
#  (1, 2.51589812319, -0.0499116593066),
#  (1, 2.44066636811, 1.7902652702200001),
#  (1, 1.2687371433399999, 1.6001557062399998),
#  (1, 1.18882147375, 0.835785599258),
#  (1, 2.61853745567, 1.3914855705000002),
#  (1, 1.66302681695, 4.12546177078),
#  (-1, -0.6901847264030001, 0.9305788179919999),
#  (-1, -0.38763050966300006, -0.7167389904699999),
#  (-1, 0.605158203746, 1.63285755088),
#  (-1, -1.8790698711200002, 0.5874868882240001),
#  (1, 2.64905777493, 1.96517548022),
#  (-1, -2.0203783868, 0.351209001229),
#  (-1, -0.95011872839, -1.45696765244),
#  (1, 3.16142190625, 0.836809838246),
#  (-1, -0.517300002823, 1.47303782745),
#  (-1, -0.341827192253, 0.085493583542),
#  (-1, -0.389458193477, -1.66988184442),
#  (-1, -0.892315157386, -1.60048370401),
#  (1, 1.45339980174, 2.1805499251900002),
#  (1, 1.15895191082, 2.08052149823),
#  (1, 1.7850763042, 2.27604167947),
#  (1, 1.74556588333, 3.25772123831),
#  (-1, 0.573551764016, -1.44885562704),
#  (1, 1.38321147969, 0.741397802147),
#  (-1, 1.10003839773, -0.110939278537),
#  (-1, -1.37960965229, -0.8405942824779999),
#  (1, 1.6421221181, 3.5225319246199995),
#  (-1, 0.7094754464569999, -0.368796778988),
#  (-1, 1.39605278347, 0.528091382458),
#  (-1, -0.349762224616, -0.696985048047),
#  (1, 2.31504419468, 1.1939383507999999),
#  (1, 0.21218358607299997, 2.70099967859),
#  (-1, -0.239311336448, 1.36249958234),
#  (1, 1.8286382733700002, 1.60803617252),
#  (-1, 0.277534489548, -0.758549412294),
#  (1, 2.58659463351, 2.59342363407),
#  (1, 2.0224118562599998, 3.26793283679),
#  (-1, -0.20845657596500003, 1.26844332075),
#  (1, 2.45055007277, 1.4403279591999998),
#  (-1, 0.725817118862, -1.2699522803799999),
#  (1, 1.04966012188, 1.4893544377099999),
#  (-1, 0.320264683263, -0.733109409979),
#  (-1, 2.13877674803, -1.54666437975),
#  (-1, -0.963075012443, 0.807908786038),
#  (-1, -0.40541499776900003, 1.06974685088),
#  (-1, -0.53942691245, -0.935384406949),
#  (1, 4.46599203536, 1.11007294541),
#  (1, 3.25526064709, -0.0372752602586),
#  (-1, -0.37166152765199995, 1.37134415028),
#  (-1, -0.726213529703, -1.20840446628),
#  (1, 2.1679819895200003, -0.247935889859),
#  (1, 2.1467657660299997, 2.8374688190900006),
#  (-1, 0.660295955223, -0.969696458955),
#  (1, 2.31104387273, 2.1157022255799998),
#  (1, 3.0109197474799996, 1.51983710014),
#  (-1, -1.03366771262, -0.147538937784),
#  (1, 4.24517619042, 3.05393139864),
#  (1, 2.4379354744299997, 1.35780395589),
#  (-1, -1.87663766373, 1.5333975233000001),
#  (1, -6.824446480190001, -13.934210941199998),
#  (-1, 0.00180474151159, 0.8651474836149999)]
